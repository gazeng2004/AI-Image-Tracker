# %%
import numpy
import pandas
from torch.utils.tensorboard import SummaryWriter
import wandb
import glob
from PIL import Image
import matplotlib.pyplot as plt
import os

# %%
img = Image.open("../data/BigGAN/n01440764_10026.JPEG")

plt.imshow(img)
plt.axis("off")

# %%
img = Image.open("/kaggle/input/datasets/renhuang8/genimage-subset-detection/gan_pool/00000.png")

plt.imshow(img)
plt.axis("off")
